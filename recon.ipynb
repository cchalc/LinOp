# %%
# Generic import statments
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn

# %%
# Google API
import googlemaps
from datetime import datetime

# api_key=print(os.getenv('API_KEY', -9999)) # quick check to make sure the right api key is being used
#key = os.getenv('API_KEY', -9999) 
gmaps = googlemaps.Client(key=os.getenv('API_KEY', -9999))

# %%
# Read in CSV files
potentialBusStops = pd.read_csv('Potentail_Bust_Stops.csv')
#potentialBusStops # Check the table
employeeAdresses = pd.read_csv('Employee_Addresses.csv')
employeeAdresses
# Out:
#                                                 address  employee_id
# 0         98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1              237 Accacia St, Daly City, CA 94014, USA         2081
# 2          1835 Folsom St, San Francisco, CA 94103, USA          178
# 3        170 Cambridge St, San Francisco, CA 94134, USA           50
# 4           16 Roanoke St, San Francisco, CA 94131, USA         1863
# 5             222 Whittier St, Daly City, CA 94014, USA          485
# 6              13 Hyde St, San Francisco, CA 94102, USA          489
# 7             2919 Geneva Ave, Daly City, CA 94014, USA         1200
# 8           100 Larkin St, San Francisco, CA 94102, USA          336
# 9           230 Murray St, San Francisco, CA 94112, USA         2015
# 10          45 Sanchez St, San Francisco, CA 94114, USA         1526
# 11           2300 16th St, San Francisco, CA 94103, USA           68
# 12            838 Schwerin St, Daly City, CA 94014, USA         1168
# ...
